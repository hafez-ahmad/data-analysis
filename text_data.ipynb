# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import nltk

# %%
sentence="""hafez ahmad is a big data and geospatial analyst , data scientist"""

# %%
sentence
# Out:
# 'hafez ahmad is a big data and geospatial analyst , data scientist'

# %%
token=nltk.word_tokenize(sentence)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
token
# Out:
# ['hafez',
#  'ahmad',
#  'is',
#  'a',
#  'big',
#  'data',
#  'and',
#  'geospatial',
#  'analyst',
#  ',',
#  'data',
#  'scientist']

# %%
tagg=nltk.pos_tag(token)
tagg
# Out:
# [('hafez', 'NN'),
#  ('ahmad', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('big', 'JJ'),
#  ('data', 'NN'),
#  ('and', 'CC'),
#  ('geospatial', 'JJ'),
#  ('analyst', 'NN'),
#  (',', ','),
#  ('data', 'NNS'),
#  ('scientist', 'NN')]

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
entities=nltk.chunk.ne_chunk(tagg)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
from nltk.corpus import treebank
t=treebank.parsed_sents('wsj_0001.mrg')[0]
t.draw()

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# True

# %%
import wordcloud

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = "square"

x, y = np.ogrid[:300, :300]

mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)


wc = WordCloud(background_color="white", mask=mask)
wc.generate(text)

plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %%
text=("python cyphton matplotlib c++ python R opencv opencv sklearn scipy hafez ahmad hafez ocean data analysis numpy pytorch tensorflow python java matlab matlab matlab apython python scipy scipi scipi numpy numpy numpy ")

# %%
text
# Out:
# 'python cyphton matplotlib c++ python R opencv opencv sklearn scipy hafez ahmad hafez ocean data analysis numpy pytorch tensorflow python java matlab matlab matlab apython python scipy scipi scipi numpy numpy numpy '

# %%
wordcloud=WordCloud(width=4000,height=4000,margin=0).generate(text)

# %%
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.margins(x=0,y=0)
plt.show()

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
wordcloud=WordCloud(relative_scaling=1.0,stopwords=set(STOPWORDS)).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import urllib
import requests
import numpy as np
import matplotlib.pyplot as plt

words = 'access guest guest apartment area area bathroom bed bed bed bed bed bedroom block coffee coffee coffee coffee entrance entry francisco free garden guest home house kettle kettle kitchen kitchen kitchen kitchen kitchen kitchenliving located microwave neighborhood new park parking place privacy private queen room san separate seperate shared space space space street suite time welcome'
mask = np.array(Image.open(requests.get('http://www.clker.com/cliparts/O/i/x/Y/q/P/yellow-house-hi.png', stream=True).raw))

# This function takes in your text and your mask and generates a wordcloud. 
def generate_wordcloud(words, mask):
    word_cloud = WordCloud(width = 512, height = 512, background_color='white', stopwords=STOPWORDS, mask=mask).generate(words)
    plt.figure(figsize=(10,8),facecolor = 'white', edgecolor='blue')
    plt.imshow(word_cloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()
    
#Run the following to generate your wordcloud
generate_wordcloud(words, mask)

# %%
words = 'access guest guest apartment area area bathroom bed bed bed bed bed bedroom block coffee coffee coffee coffee entrance entry francisco free garden guest home house kettle kettle kitchen kitchen kitchen kitchen kitchen kitchenliving located microwave neighborhood new park parking place privacy private queen room san separate seperate shared space space space street suite time welcome'

# %%
img=Image.open("G:/203659137.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=325x325 at 0x9A02E5C438>

# %%
mask=np.array(img,dtype='uint8')

# %%
mask
# Out:
# array([[[101, 204, 247],
#         [101, 204, 247],
#         [101, 204, 247],
#         ...,
#         [103, 205, 245],
#         [103, 205, 245],
#         [103, 205, 245]],
#
#        [[101, 204, 246],
#         [101, 204, 246],
#         [101, 204, 246],
#         ...,
#         [104, 206, 246],
#         [104, 206, 246],
#         [104, 206, 246]],
#
#        [[102, 206, 245],
#         [102, 206, 245],
#         [102, 206, 245],
#         ...,
#         [105, 208, 246],
#         [105, 208, 246],
#         [105, 208, 246]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [110, 166,  34],
#         [162, 204,  77],
#         [117, 158,  31]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [138, 190,  77],
#         [189, 231, 113],
#         [136, 178,  51]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [104, 149,  44],
#         [110, 157,  40],
#         [117, 167,  32]]], dtype=uint8)

# %%
mask.shape
# Out:
# (325, 325, 3)

# %%
plt.imshow(mask)

# %%
img=Image.open("G:/203659137.png")

# %%
# This function takes in your text and your mask and generates a wordcloud. 
def generate_wordcloud(words, mask):
    word_cloud = WordCloud(width = 512, height = 512, background_color='white', stopwords=STOPWORDS, mask=mask).generate(words)
    plt.figure(figsize=(10,8),facecolor = 'white', edgecolor='blue')
    plt.imshow(word_cloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()
    
#Run the following to generate your wordcloud
generate_wordcloud(words, mask)
